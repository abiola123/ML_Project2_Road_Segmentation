# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf
import os
import sys
import matplotlib.image as mpimg
import numpy as np
import matplotlib.pyplot as plt

# %%
# Constants
IMG_WIDTH = 400
IMG_HEIGHT = 400
IMG_CHANNELS = 3

# %%
# Model
#dropouts were added to avoid overfitting

#Encoder Path
inputs = tf.keras.layers.Input((IMG_WIDTH,IMG_HEIGHT,IMG_CHANNELS))

#transform input which can be integer value into floating point values
transform = tf.keras.layers.Lambda(lambda x : x / 255.0)(inputs)

#first convolution
c1 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(transform)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(c1)

#first pooling
p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)

#second convolution
c2 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(c2)

#second pooling
p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)

#third convolution
c3 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(p2)
c3 = tf.keras.layers.Dropout(0.1)(c3)
c3 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(c3)

#third pooling
p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)

#fourth convolution
c4 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(p3)
c4 = tf.keras.layers.Dropout(0.1)(c4)
c4 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(c4)

#fourth pooling
p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)

#fifth convolution
c5 = tf.keras.layers.Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(p4)
c5 = tf.keras.layers.Dropout(0.1)(c5)
c5 = tf.keras.layers.Conv2D(256, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(c5)


#Decoder Path
#at each step we concatenate the results from the encoder path with the results from the deocder path => improves image segmentation


#first upsampling
u1 = tf.keras.layers.Conv2DTranspose(128, (2,2), strides = (2,2), padding="same")(c5)
u1 = tf.keras.layers.concatenate([u1, c4])
u1 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u1)
u1 = tf.keras.layers.Dropout(0.1)(u1)
u1 = tf.keras.layers.Conv2D(128, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u1)

#second upsampling
u2 = tf.keras.layers.Conv2DTranspose(64, (2,2), strides = (2,2), padding="same")(u1)
u2 = tf.keras.layers.concatenate([u2, c3])
u2 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u2)
u2 = tf.keras.layers.Dropout(0.1)(u2)
u2 = tf.keras.layers.Conv2D(64, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u2)

#third upsampling
u3 = tf.keras.layers.Conv2DTranspose(32, (2,2), strides = (2,2), padding="same")(u2)
u3 = tf.keras.layers.concatenate([u3, c2])
u3 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u3)
u3 = tf.keras.layers.Dropout(0.1)(u3)
u3 = tf.keras.layers.Conv2D(32, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u3)

#fourth upsampling
u4 = tf.keras.layers.Conv2DTranspose(16, (2,2), strides = (2,2), padding="same")(u3)
u4 = tf.keras.layers.concatenate([u4, c1])
u4 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u4)
u4 = tf.keras.layers.Dropout(0.1)(u4)
u4 = tf.keras.layers.Conv2D(16, (3,3), activation="relu", kernel_initializer="he_normal",padding="same")(u4)

out = tf.keras.layers.Conv2D(1, (1,1), activation="sigmoid")(u4)

model = tf.keras.Model(inputs = [inputs], outputs=[out])
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 400, 400, 3)  0
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 400, 400, 3)  0           input_15[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 400, 400, 16) 448         lambda_11[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 400, 400, 16) 0           conv2d_189[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 400, 400, 16) 2320        dropout_90[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_44 (MaxPooling2D) (None, 200, 200, 16) 0           conv2d_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 200, 200, 32) 4640        max_pooling2d_44[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 200, 200, 32) 0           conv2d_191[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 200, 200, 32) 9248        dropout_91[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_45 (MaxPooling2D) (None, 100, 100, 32) 0           conv2d_192[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 100, 100, 64) 18496       max_pooling2d_45[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 100, 100, 64) 0           conv2d_193[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 100, 100, 64) 36928       dropout_92[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_46 (MaxPooling2D) (None, 50, 50, 64)   0           conv2d_194[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 50, 50, 128)  73856       max_pooling2d_46[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 50, 50, 128)  0           conv2d_195[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 50, 50, 128)  147584      dropout_93[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_47 (MaxPooling2D) (None, 25, 25, 128)  0           conv2d_196[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 25, 25, 256)  295168      max_pooling2d_47[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 25, 25, 256)  0           conv2d_197[0][0]
# __________________________________________________________________________________________________
# conv2d_198 (Conv2D)             (None, 25, 25, 256)  590080      dropout_94[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_41 (Conv2DTran (None, 50, 50, 128)  131200      conv2d_198[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 50, 50, 256)  0           conv2d_transpose_41[0][0]
#                                                                  conv2d_196[0][0]
# __________________________________________________________________________________________________
# conv2d_199 (Conv2D)             (None, 50, 50, 128)  295040      concatenate_38[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 50, 50, 128)  0           conv2d_199[0][0]
# __________________________________________________________________________________________________
# conv2d_200 (Conv2D)             (None, 50, 50, 128)  147584      dropout_95[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_42 (Conv2DTran (None, 100, 100, 64) 32832       conv2d_200[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 100, 100, 128 0           conv2d_transpose_42[0][0]
#                                                                  conv2d_194[0][0]
# __________________________________________________________________________________________________
# conv2d_201 (Conv2D)             (None, 100, 100, 64) 73792       concatenate_39[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 100, 100, 64) 0           conv2d_201[0][0]
# __________________________________________________________________________________________________
# conv2d_202 (Conv2D)             (None, 100, 100, 64) 36928       dropout_96[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_43 (Conv2DTran (None, 200, 200, 32) 8224        conv2d_202[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 200, 200, 64) 0           conv2d_transpose_43[0][0]
#                                                                  conv2d_192[0][0]
# __________________________________________________________________________________________________
# conv2d_203 (Conv2D)             (None, 200, 200, 32) 18464       concatenate_40[0][0]
# __________________________________________________________________________________________________
# dropout_97 (Dropout)            (None, 200, 200, 32) 0           conv2d_203[0][0]
# __________________________________________________________________________________________________
# conv2d_204 (Conv2D)             (None, 200, 200, 32) 9248        dropout_97[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_44 (Conv2DTran (None, 400, 400, 16) 2064        conv2d_204[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 400, 400, 32) 0           conv2d_transpose_44[0][0]
#                                                                  conv2d_190[0][0]
# __________________________________________________________________________________________________
# conv2d_205 (Conv2D)             (None, 400, 400, 16) 4624        concatenate_41[0][0]
# __________________________________________________________________________________________________
# dropout_98 (Dropout)            (None, 400, 400, 16) 0           conv2d_205[0][0]
# __________________________________________________________________________________________________
# conv2d_206 (Conv2D)             (None, 400, 400, 16) 2320        dropout_98[0][0]
# __________________________________________________________________________________________________
# conv2d_207 (Conv2D)             (None, 400, 400, 1)  17          conv2d_206[0][0]
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Define our data (inputs and labels)
def load_image(infilename):
    data = mpimg.imread(infilename)
    return data

# Assign a label to a patch v
def value_to_class(v):
    foreground_threshold = 0.25  # percentage of pixels > 1 required to assign a foreground label to a patch
    df = np.sum(v)
    if df > foreground_threshold:  # road
        return [0, 1]
    else:  # bgrd
        return [1, 0]
    
TRAIN_PATH = "/Users/abiola/Documents/EPFL/ML_Project2_Road_Segmentation/Ressources/training/"
TEST_PATH = "/Users/abiola/Documents/EPFL/ML_Project2_Road_Segmentation/Ressources/test_set_images/"

n = 20

image_dir = TRAIN_PATH + "images/"
files = os.listdir(image_dir)

imgs = [load_image(image_dir + files[i]) for i in range(n)]
imgs = np.asarray(imgs)

gt_dir = TRAIN_PATH + "groundtruth/"
files = os.listdir(gt_dir)

gt_imgs = [load_image(gt_dir + files[i]) for i in range(n)]
gt_imgs = np.asarray(gt_imgs)

mask = np.where(gt_imgs > 0.1)
labels = np.zeros(gt_imgs.shape)
labels[mask] = 1

X = imgs
Y = labels.reshape(n,IMG_WIDTH,IMG_WIDTH,1)

print(Y.shape)
print(X.shape)
# Out:
# (20, 400, 400, 1)
# (20, 400, 400, 3)

# %%
# Show some images to see if everything is fine

PIXEL_DEPTH = 255

def img_float_to_uint8(img):
    rimg = img - np.min(img)
    rimg = (rimg / np.max(rimg) * PIXEL_DEPTH).round().astype(np.uint8)
    return rimg

def concatenate_images(img, gt_img):
    n_channels = len(gt_img.shape)
    w = gt_img.shape[0]
    h = gt_img.shape[1]
    if n_channels == 3:
        cimg = np.concatenate((img, gt_img), axis=1)
    else:
        gt_img_3c = np.zeros((w, h, 3), dtype=np.uint8)
        gt_img8 = img_float_to_uint8(gt_img)          
        gt_img_3c[:, :, 0] = gt_img8
        gt_img_3c[:, :, 1] = gt_img8
        gt_img_3c[:, :, 2] = gt_img8
        img8 = img_float_to_uint8(img)
        cimg = np.concatenate((img8, gt_img_3c), axis=1)
    return cimg

gt = Y.reshape((-1,400,400))
cimg = concatenate_images(X[10],gt[10])
fig1 = plt.figure(figsize=(10, 10))
plt.imshow(cimg, cmap='Greys_r')

# %%
#Callbacks for fit methods

#1. checkpoints to save timestamps of model during training
checkpoints = tf.keras.callbacks.ModelCheckpoint("road_semgentation_unet.h5", verbose=1, save_best_only = True)

#2. eraly stopping callback to avoid useless epochs
early_stopping = tf.keras.callbacks.EarlyStopping(patience=4, monitor="val_loss")

#3. tensorboard to visulaize various statistics during training
tensorboard = tf.keras.callbacks.TensorBoard(log_dir='logs')

callbacks = [checkpoints,early_stopping,tensorboard]

# %%
results = model.fit(X,Y,validation_split = 0.1, batch_size=16 , epochs = 30, callbacks = callbacks)
# Out:
# Train on 18 samples, validate on 2 samples
# Epoch 1/30
# 16/18 [=========================>....] - ETA: 2s - loss: 11.0881 - acc: 0.6560
# Epoch 00001: val_loss improved from inf to 1.37034, saving model to road_semgentation_unet.h5
# 18/18 [==============================] - 26s 1s/step - loss: 10.0094 - acc: 0.6789 - val_loss: 1.3703 - val_acc: 0.7887
# Epoch 2/30
# 16/18 [=========================>....] - ETA: 2s - loss: 10.9141 - acc: 0.8308
# Epoch 00002: val_loss improved from 1.37034 to 1.08630, saving model to road_semgentation_unet.h5
# 18/18 [==============================] - 20s 1s/step - loss: 9.8421 - acc: 0.8295 - val_loss: 1.0863 - val_acc: 0.7884
# Epoch 3/30
# 16/18 [=========================>....] - ETA: 1s - loss: 8.3406 - acc: 0.8332
# Epoch 00003: val_loss did not improve from 1.08630
# 18/18 [==============================] - 16s 904ms/step - loss: 7.5434 - acc: 0.8295 - val_loss: 1.3235 - val_acc: 0.7887
# Epoch 4/30
# 16/18 [=========================>....] - ETA: 1s - loss: 10.3192 - acc: 0.8306
# Epoch 00004: val_loss did not improve from 1.08630
# 18/18 [==============================] - 16s 869ms/step - loss: 9.3187 - acc: 0.8317 - val_loss: 1.3401 - val_acc: 0.7887
# Epoch 5/30
# 16/18 [=========================>....] - ETA: 1s - loss: 10.6154 - acc: 0.8310
# Epoch 00005: val_loss did not improve from 1.08630
# 18/18 [==============================] - 15s 834ms/step - loss: 9.5827 - acc: 0.8320 - val_loss: 1.3324 - val_acc: 0.7887
# Epoch 6/30
# 16/18 [=========================>....] - ETA: 1s - loss: 10.5635 - acc: 0.8293
# Epoch 00006: val_loss did not improve from 1.08630
# 18/18 [==============================] - 16s 887ms/step - loss: 9.5347 - acc: 0.8320 - val_loss: 1.3157 - val_acc: 0.7887

# %%
#Testing our model
